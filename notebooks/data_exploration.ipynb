# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('../data/raw/aact_txt_files/designs.txt', sep='|')
# Out:
#                id       nct_id      allocation intervention_model  \
# 0       151097792  NCT03539705             NaN                NaN
# 1       151097793  NCT05781542      RANDOMIZED       SINGLE_GROUP
# 2       150651222  NCT03821272      RANDOMIZED           PARALLEL
# 3       150651223  NCT05904769  NON_RANDOMIZED           PARALLEL
# 4       150651224  NCT06246526  NON_RANDOMIZED       SINGLE_GROUP
# ...           ...          ...             ...                ...
# 557093  150986432  NCT06876701             NaN       SINGLE_GROUP
# 557094  150986433  NCT07208903             NaN                NaN
# 557095  150986434  NCT07208201             NaN                NaN
# 557096  150986435  NCT07207642             NaN                NaN
# 557097  150986436  NCT07209059             NaN       SINGLE_GROUP
#
#        observational_model           primary_purpose time_perspective masking  \
# 0                    OTHER                       NaN            OTHER     NaN
# ...
